# %%
import numpy as np

A0 = np.array([[3], [2], [5]])
W1 = np.array([[1.1, -1.3, 1.5], [0.1, 2.0, 1.7]])
W2 = np.array([[2.0, -1.2]])

A1 = np.dot(W1, A0)
A2 = np.dot(W2, A1)

# %%
print("Matriisi A1:")
print(A1)
print("Matriisi A2:")
print(A2)
# Out:
# Matriisi A1:
# [[ 8.2]
#  [12.8]]
# Matriisi A2:
# [[1.04]]
